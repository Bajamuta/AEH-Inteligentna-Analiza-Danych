# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn import tree

# %%
iris = load_iris()
x = pd.DataFrame(iris.data[:, :], columns = iris.feature_names[:])
y = pd.DataFrame(iris.target, columns =["Species"])

# %%
print(x.shape)
print(y.shape)
# Out:
# (150, 4)
# (150, 1)

# %%
print(x[1:5])
print(y[1:5])
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#    Species
# 1        0
# 2        0
# 3        0
# 4        0

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x, y)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(14, 14))
tree.plot_tree(clf, feature_names=list(x.columns), class_names=iris.target_names)
# Out:
# [Text(390.6, 697.62, 'petal width (cm) <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(330.50769230769237, 570.78, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(450.69230769230774, 570.78, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(240.3692307692308, 443.94, 'petal length (cm) <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(120.1846153846154, 317.1, 'petal width (cm) <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]\nclass = versicolor'),
#  Text(60.0923076923077, 190.26, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]\nclass = versicolor'),
#  Text(180.27692307692308, 190.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(360.55384615384617, 317.1, 'petal width (cm) <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(300.4615384615385, 190.26, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(420.6461538461539, 190.26, 'sepal length (cm) <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(360.55384615384617, 63.42000000000007, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(480.7384615384616, 63.42000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(661.0153846153847, 443.94, 'petal length (cm) <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]\nclass = virginica'),
#  Text(600.923076923077, 317.1, 'sepal length (cm) <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(540.8307692307693, 190.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(661.0153846153847, 190.26, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(721.1076923076923, 317.1, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]\nclass = virginica')]

# %%
# [sepal length, sepal width, petal length, petal width
iris.target_names[int(clf.predict([[3, 5, 3, 3]]))]
# Out:
# /home/wiktor/.local/lib/python3.8/site-packages/sklearn/base.py:441: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 'versicolor'

# %%
# Prosze zaproponowac takie dwa zestawy cech, aby zostały zakwalifikowane przez drzewo do klas 'virginica' i 'versicolor'

# %%
# Maksymalna głębokość drzewa równa 2

# %%
clf_max_depth_equal_to_2 = tree.DecisionTreeClassifier(max_depth=2)
clf_max_depth_equal_to_2 = clf_max_depth_equal_to_2.fit(x, y)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(14, 14))
tree.plot_tree(clf_max_depth_equal_to_2, feature_names=list(x.columns), class_names=iris.target_names)
# Out:
# [Text(312.48, 634.1999999999999, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(156.24, 380.52, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(468.72, 380.52, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(312.48, 126.84000000000003, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(624.96, 126.84000000000003, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]\nclass = virginica')]

# %%
# Ewaluacja dwóch wariantów drzew

# %%
y_pred_from_clf = clf.predict(x)
y_pred_from_clf_max_depth_equal_to_2 = clf_max_depth_equal_to_2.predict(x)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y, y_pred_from_clf)
# Out:
# 1.0

# %%
accuracy_score(y, y_pred_from_clf_max_depth_equal_to_2)
# Out:
# 0.96

# %%
# Proszę sprawdzic jak zmieni sie accurracy gdy ustawimy maksymalna glebokosc drzewa na 1

# %%
# Czy accurracy na poziomie 1.0 dla tak przetestowanego zbioru danych oznacza, że zbudowaliśmy idealny klasyfikator?
