# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn import tree

# %%
iris = load_iris()
x = pd.DataFrame(iris.data[:, :], columns = iris.feature_names[:])
y = pd.DataFrame(iris.target, columns =["Species"])

# %%
print(x.shape)
print(y.shape)
# Out:
# (150, 4)
# (150, 1)

# %%
print(x[1:5])
print(y[1:5])
# 1-50:0, 51-100:1, 101-150:2
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#    Species
# 1        0
# 2        0
# 3        0
# 4        0

# %%
print(y)
# Out:
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %%
y = y[0:110]
x = x[0:110]
y[0:100] = 0
print(y[90:])
# Out:
#      Species
# 90         0
# 91         0
# 92         0
# 93         0
# 94         0
# 95         0
# 96         0
# 97         0
# 98         0
# 99         0
# 100        2
# 101        2
# 102        2
# 103        2
# 104        2
# 105        2
# 106        2
# 107        2
# 108        2
# 109        2

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)

# %%
clf = tree.DecisionTreeClassifier(max_depth=2)
clf = clf.fit(x_train, y_train)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(14, 14))
tree.plot_tree(clf, feature_names=list(x.columns), class_names=iris.target_names)
# Out:
# [Text(312.48, 634.1999999999999, 'petal width (cm) <= 1.65\ngini = 0.182\nsamples = 99\nvalue = [89, 10]\nclass = setosa'),
#  Text(156.24, 380.52, 'gini = 0.0\nsamples = 87\nvalue = [87, 0]\nclass = setosa'),
#  Text(468.72, 380.52, 'petal length (cm) <= 5.05\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = versicolor'),
#  Text(312.48, 126.84000000000003, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = setosa'),
#  Text(624.96, 126.84000000000003, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = versicolor')]

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 1.0

# %%
# Czy takie wyniki są zadawalające?

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[11]]

# %%
# Czy model został przetestowany w odpowiedni sposób?
